# %%
import pandas as pd
from bs4 import BeautifulSoup
import pymysql, calendar, time, json
import requests
from datetime import datetime
from threading import Timer

# %%
class DBUpdater:  
    def __init__(self):
        """생성자: MariaDB 연결 및 종목코드 딕셔너리 생성"""
        self.conn = pymysql.connect(host='localhost', user='root',
            password='1234', db='INVESTAR', charset='utf8')
        
        with self.conn.cursor() as curs:
            sql = """
            CREATE TABLE IF NOT EXISTS company_info (
                code VARCHAR(20),
                company VARCHAR(40),
                last_update DATE,
                PRIMARY KEY (code))
            """
            curs.execute(sql)
            sql = """
            CREATE TABLE IF NOT EXISTS daily_price (
                code VARCHAR(20),
                date DATE,
                open BIGINT(20),
                high BIGINT(20),
                low BIGINT(20),
                close BIGINT(20),
                diff BIGINT(20),
                volume BIGINT(20),
                PRIMARY KEY (code, date))
            """
            curs.execute(sql)
        self.conn.commit()
        self.codes = dict()
               
    def __del__(self):
        """소멸자: MariaDB 연결 해제"""
        self.conn.close() 
     
    def read_krx_code(self):
        """KRX로부터 상장기업 목록 파일을 읽어와서 데이터프레임으로 반환"""
        url = 'http://kind.krx.co.kr/corpgeneral/corpList.do?method='\
            'download&searchType=13'
        krx = pd.read_html(url, header=0)[0]
        krx = krx[['종목코드', '회사명']]
        krx = krx.rename(columns={'종목코드': 'code', '회사명': 'company'})
        krx.code = krx.code.map('{:06d}'.format)
        return krx
    
    def update_comp_info(self):
        """종목코드를 company_info 테이블에 업데이트 한 후 딕셔너리에 저장"""
        sql = "SELECT * FROM company_info"
        df = pd.read_sql(sql, self.conn)
        for idx in range(len(df)):
            self.codes[df['code'].values[idx]] = df['company'].values[idx]
                    
        with self.conn.cursor() as curs:
            sql = "SELECT max(last_update) FROM company_info"
            curs.execute(sql)
            rs = curs.fetchone()
            today = datetime.today().strftime('%Y-%m-%d')
            if rs[0] == None or rs[0].strftime('%Y-%m-%d') < today:
                krx = self.read_krx_code()
                for idx in range(len(krx)):
                    print("=============")
                    print(krx.code)
                    code = krx.code.values[idx]
                    company = krx.company.values[idx]                
                    sql = f"REPLACE INTO company_info (code, company, last"\
                        f"_update) VALUES ('{code}', '{company}', '{today}')"
                    curs.execute(sql)
                    self.codes[code] = company
                    tmnow = datetime.now().strftime('%Y-%m-%d %H:%M')
                    print(f"[{tmnow}] #{idx+1:04d} REPLACE INTO company_info "\
                        f"VALUES ({code}, {company}, {today})")
                self.conn.commit()
                print('')              

    def read_naver(self, code, company, pages_to_fetch):
        """네이버에서 주식 시세를 읽어서 데이터프레임으로 반환"""
        try:
            url = f"http://finance.naver.com/item/sise_day.nhn?code={code}"
            html = BeautifulSoup(requests.get(url,
                headers={'User-agent': 'Mozilla/5.0'}).text, "lxml")
            pgrr = html.find("td", class_="pgRR")
            if pgrr is None:
                return None
            s = str(pgrr.a["href"]).split('=')
            lastpage = s[-1] 
            df = pd.DataFrame()
            pages = min(int(lastpage), pages_to_fetch)
            for page in range(1, pages + 1):
                pg_url = '{}&page={}'.format(url, page)
                df = df.append(pd.read_html(requests.get(pg_url,
                    headers={'User-agent': 'Mozilla/5.0'}).text)[0])                                          
                tmnow = datetime.now().strftime('%Y-%m-%d %H:%M')
                print('[{}] {} ({}) : {:04d}/{:04d} pages are downloading...'.
                    format(tmnow, company, code, page, pages), end="\r")
           
            df = df.rename(columns={'날짜':'date','종가':'close','전일비':'diff'
                ,'시가':'open','고가':'high','저가':'low','거래량':'volume'})
            df['date'] = df['date'].replace('.', '-')
            df = df.dropna()
            df[['close', 'diff', 'open', 'high', 'low', 'volume']] = df[['close',
                'diff', 'open', 'high', 'low', 'volume']].astype(int)
            df = df[['date', 'open', 'high', 'low', 'close', 'diff', 'volume']]
        except Exception as e:
            print('Exception occured :', str(e))
            return None
        return df
    
    # 네이버에서 읽어온 주식 시세를 DB에 REPLACE
    def replace_into_db(self, df, num, code, company):
        with self.conn.cursor() as curs:
            for r in df.itertuples():
                sql = f"REPLACE INTO daily_price VALUES ('{code}', "\
                    f"'{r.date}', {r.open}, {r.high}, {r.low}, {r.close}, "\
                    f"{r.diff}, {r.volume})"
                curs.execute(sql)
            self.conn.commit()
            print('[{}] #{:04d} {} ({}) : {} rows > REPLACE INTO daily_'\
                'price [OK]'.format(datetime.now().strftime('%Y-%m-%d'\
                ' %H:%M'), num+1, company, code, len(df)))
    
    def update_daily_price(self, pages_to_fetch):
        for idx, code in enumerate(self.codes):

            if idx < 5:
                df = self.read_naver(code, self.codes[code], pages_to_fetch)
                if df is None:
                    continue
                self.replace_into_db(df, idx, code, self.codes[code])
            
            # 특정 주식만 넣고 싶은 경우 아래와 같이 한다
            # if code == '000660':#'005930':
            #     df = self.read_naver(code, self.codes[code], pages_to_fetch)
            #     if df is None:
            #         continue
            #     self.replace_into_db(df, idx, code, self.codes[code])
    
    # --------------------------------------------------
    def execute_daily(self):
        self.update_comp_info()
        
        try:
            with open('config.json', 'r') as in_file:
                config = json.load(in_file)
                pages_to_fetch = config['pages_to_fetch']
        except FileNotFoundError:
            with open('config.json', 'w') as out_file:
                pages_to_fetch = 100
                config = {'pages_to_fetch': pages_to_fetch}
                json.dump(config, out_file)                
        
        self.update_daily_price(pages_to_fetch)
    
    # --------------------------------------------------

# %%
dbu = DBUpdater()
df = dbu.execute_daily()
df
# Out:
#         종목코드        회사명
# 0       4840      DRB동일
# 1     155660        DSR
# 2      78930         GS
# 3       1250      GS글로벌
# 4     294870  HDC현대산업개발
# ...      ...        ...
# 2477  199800         툴젠
# 2478  217880         틸론
# 2479  222670   플럼라인생명과학
# 2480  331660   한국미라클피플사
# 2481  212310        휴벡셀
#
# [2482 rows x 2 columns]
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0001 REPLACE INTO company_info VALUES (004840, DRB동일, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0002 REPLACE INTO company_info VALUES (155660, DSR, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0003 REPLACE INTO company_info VALUES (078930, GS, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0004 REPLACE INTO company_info VALUES (001250, GS글로벌, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0005 REPLACE INTO company_info VALUES (294870, HDC현대산업개발, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0006 REPLACE INTO company_info VALUES (011200, HMM, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0007 REPLACE INTO company_info VALUES (092220, KEC, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0008 REPLACE INTO company_info VALUES (016380, KG동부제철, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0009 REPLACE INTO company_info VALUES (001390, KG케미칼, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0010 REPLACE INTO company_info VALUES (058860, KTis, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0011 REPLACE INTO company_info VALUES (011070, LG이노텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0012 REPLACE INTO company_info VALUES (037560, LG헬로비전, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0013 REPLACE INTO company_info VALUES (010060, OCI, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0014 REPLACE INTO company_info VALUES (402340, SK스퀘어, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0015 REPLACE INTO company_info VALUES (096770, SK이노베이션, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0016 REPLACE INTO company_info VALUES (011810, STX, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0017 REPLACE INTO company_info VALUES (024070, WISCOM, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0018 REPLACE INTO company_info VALUES (011420, 갤럭시아에스엠, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0019 REPLACE INTO company_info VALUES (002100, 경농, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0020 REPLACE INTO company_info VALUES (012320, 경동인베스트, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0021 REPLACE INTO company_info VALUES (007690, 국도화학, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0022 REPLACE INTO company_info VALUES (005320, 국동, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0023 REPLACE INTO company_info VALUES (014530, 극동유화, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0024 REPLACE INTO company_info VALUES (013700, 까뮤이앤씨, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0025 REPLACE INTO company_info VALUES (353200, 대덕전자, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0026 REPLACE INTO company_info VALUES (128820, 대성산업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0027 REPLACE INTO company_info VALUES (047040, 대우건설, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0028 REPLACE INTO company_info VALUES (003090, 대웅, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0029 REPLACE INTO company_info VALUES (145720, 덴티움, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0030 REPLACE INTO company_info VALUES (026890, 디피씨, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0031 REPLACE INTO company_info VALUES (286940, 롯데정보통신, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0032 REPLACE INTO company_info VALUES (027740, 마니커, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0033 REPLACE INTO company_info VALUES (008560, 메리츠증권, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0034 REPLACE INTO company_info VALUES (017180, 명문제약, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0035 REPLACE INTO company_info VALUES (204210, 모두투어리츠, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0036 REPLACE INTO company_info VALUES (003850, 보령제약, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0037 REPLACE INTO company_info VALUES (001270, 부국증권, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0038 REPLACE INTO company_info VALUES (006400, 삼성SDI, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0039 REPLACE INTO company_info VALUES (028050, 삼성엔지니어링, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0040 REPLACE INTO company_info VALUES (068290, 삼성출판사, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0041 REPLACE INTO company_info VALUES (000810, 삼성화재해상보험, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0042 REPLACE INTO company_info VALUES (003720, 삼영화학공업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0043 REPLACE INTO company_info VALUES (010960, 삼호개발, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0044 REPLACE INTO company_info VALUES (001290, 상상인증권, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0045 REPLACE INTO company_info VALUES (136490, 선진, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0046 REPLACE INTO company_info VALUES (002420, 세기상사, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0047 REPLACE INTO company_info VALUES (004490, 세방전지, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0048 REPLACE INTO company_info VALUES (003030, 세아제강지주, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0049 REPLACE INTO company_info VALUES (012600, 센트럴인사이트, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0050 REPLACE INTO company_info VALUES (293940, 신한알파리츠, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0051 REPLACE INTO company_info VALUES (055550, 신한지주, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0052 REPLACE INTO company_info VALUES (003620, 쌍용자동차, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0053 REPLACE INTO company_info VALUES (137310, 에스디바이오센서, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0054 REPLACE INTO company_info VALUES (078520, 에이블씨엔씨, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0055 REPLACE INTO company_info VALUES (012280, 영화금속, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0056 REPLACE INTO company_info VALUES (007310, 오뚜기, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0057 REPLACE INTO company_info VALUES (271560, 오리온, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0058 REPLACE INTO company_info VALUES (105840, 우진, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0059 REPLACE INTO company_info VALUES (008600, 윌비스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0060 REPLACE INTO company_info VALUES (033270, 유나이티드, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0061 REPLACE INTO company_info VALUES (023800, 인지컨트롤스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0062 REPLACE INTO company_info VALUES (129260, 인터지스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0063 REPLACE INTO company_info VALUES (013360, 일성건설, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0064 REPLACE INTO company_info VALUES (081000, 일진다이아, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0065 REPLACE INTO company_info VALUES (033240, 자화전자, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0066 REPLACE INTO company_info VALUES (271980, 제일약품, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0067 REPLACE INTO company_info VALUES (002620, 제일파마홀딩스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0068 REPLACE INTO company_info VALUES (001550, 조비, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0069 REPLACE INTO company_info VALUES (002600, 조흥, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0070 REPLACE INTO company_info VALUES (001630, 종근당홀딩스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0071 REPLACE INTO company_info VALUES (071320, 지역난방공사, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0072 REPLACE INTO company_info VALUES (120110, 코오롱인더, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0073 REPLACE INTO company_info VALUES (020120, 키다리스튜디오, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0074 REPLACE INTO company_info VALUES (015890, 태경산업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0075 REPLACE INTO company_info VALUES (004100, 태양금속공업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0076 REPLACE INTO company_info VALUES (005490, 포스코, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0077 REPLACE INTO company_info VALUES (058430, 포스코강판, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0078 REPLACE INTO company_info VALUES (005430, 한국공항, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0079 REPLACE INTO company_info VALUES (168490, 한국패러랠, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0080 REPLACE INTO company_info VALUES (009180, 한솔로지스틱스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0081 REPLACE INTO company_info VALUES (002220, 한일철강, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0082 REPLACE INTO company_info VALUES (009460, 한창제지, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0083 REPLACE INTO company_info VALUES (088350, 한화생명, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0084 REPLACE INTO company_info VALUES (000720, 현대건설, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0085 REPLACE INTO company_info VALUES (042670, 현대두산인프라코어, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0086 REPLACE INTO company_info VALUES (004560, 현대비앤지스틸, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0087 REPLACE INTO company_info VALUES (017800, 현대엘리베이터, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0088 REPLACE INTO company_info VALUES (001500, 현대차증권, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0089 REPLACE INTO company_info VALUES (111110, 호전실업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0090 REPLACE INTO company_info VALUES (060310, 3S, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0091 REPLACE INTO company_info VALUES (245620, EDGC, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0092 REPLACE INTO company_info VALUES (050120, ES큐브, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0093 REPLACE INTO company_info VALUES (195940, HK이노엔, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0094 REPLACE INTO company_info VALUES (095340, ISC, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0095 REPLACE INTO company_info VALUES (067290, JW신약, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0096 REPLACE INTO company_info VALUES (024120, KB오토시스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0097 REPLACE INTO company_info VALUES (060720, KH바텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0098 REPLACE INTO company_info VALUES (024940, PN풍년, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0099 REPLACE INTO company_info VALUES (036120, SCI평가정보, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0100 REPLACE INTO company_info VALUES (255220, SG, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0101 REPLACE INTO company_info VALUES (036490, SK머티리얼즈, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0102 REPLACE INTO company_info VALUES (032540, TJ미디어, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0103 REPLACE INTO company_info VALUES (217730, 강스템바이오텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0104 REPLACE INTO company_info VALUES (053950, 경남제약, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0105 REPLACE INTO company_info VALUES (024910, 경창산업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0106 REPLACE INTO company_info VALUES (331520, 교보9호스팩, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0107 REPLACE INTO company_info VALUES (043650, 국순당, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0108 REPLACE INTO company_info VALUES (078130, 국일제지, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0109 REPLACE INTO company_info VALUES (204020, 그리티, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0110 REPLACE INTO company_info VALUES (019660, 글로본, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0111 REPLACE INTO company_info VALUES (308100, 까스텔바작, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0112 REPLACE INTO company_info VALUES (286750, 나노브릭, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0113 REPLACE INTO company_info VALUES (151910, 나노스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0114 REPLACE INTO company_info VALUES (094860, 네오리진, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0115 REPLACE INTO company_info VALUES (095660, 네오위즈, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0116 REPLACE INTO company_info VALUES (085910, 네오티스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0117 REPLACE INTO company_info VALUES (007390, 네이처셀, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0118 REPLACE INTO company_info VALUES (054050, 농우바이오, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0119 REPLACE INTO company_info VALUES (012340, 뉴인텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0120 REPLACE INTO company_info VALUES (340360, 다보링크, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0121 REPLACE INTO company_info VALUES (078140, 대봉엘에스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0122 REPLACE INTO company_info VALUES (290380, 대유, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0123 REPLACE INTO company_info VALUES (290120, 대유에이피, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0124 REPLACE INTO company_info VALUES (003310, 대주산업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0125 REPLACE INTO company_info VALUES (060900, 대한그린파워, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0126 REPLACE INTO company_info VALUES (023910, 대한약품, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0127 REPLACE INTO company_info VALUES (006620, 동구바이오제약, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0128 REPLACE INTO company_info VALUES (086450, 동국제약, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0129 REPLACE INTO company_info VALUES (228340, 동양파일, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0130 REPLACE INTO company_info VALUES (203650, 드림시큐리티, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0131 REPLACE INTO company_info VALUES (196490, 디에이테크놀로지, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0132 REPLACE INTO company_info VALUES (066900, 디에이피, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0133 REPLACE INTO company_info VALUES (127120, 디엔에이링크, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0134 REPLACE INTO company_info VALUES (033130, 디지틀조선, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0135 REPLACE INTO company_info VALUES (060240, 룽투코리아, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0136 REPLACE INTO company_info VALUES (219420, 링크제니시스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0137 REPLACE INTO company_info VALUES (250060, 모비스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0138 REPLACE INTO company_info VALUES (118990, 모트렉스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0139 REPLACE INTO company_info VALUES (328380, 미래에셋대우스팩3호, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0140 REPLACE INTO company_info VALUES (214610, 미코바이오메드, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0141 REPLACE INTO company_info VALUES (019010, 베뉴지, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0142 REPLACE INTO company_info VALUES (337930, 브랜드엑스코퍼레이션, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0143 REPLACE INTO company_info VALUES (023600, 삼보판지, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0144 REPLACE INTO company_info VALUES (377630, 삼성스팩4호, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0145 REPLACE INTO company_info VALUES (009300, 삼아제약, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0146 REPLACE INTO company_info VALUES (032280, 삼일, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0147 REPLACE INTO company_info VALUES (252990, 샘씨엔에스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0148 REPLACE INTO company_info VALUES (100660, 서암기계공업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0149 REPLACE INTO company_info VALUES (086710, 선진뷰티사이언스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0150 REPLACE INTO company_info VALUES (080470, 성창오토텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0151 REPLACE INTO company_info VALUES (053450, 세코닉스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0152 REPLACE INTO company_info VALUES (208370, 셀바스헬스케어, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0153 REPLACE INTO company_info VALUES (115570, 스타플렉스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0154 REPLACE INTO company_info VALUES (013810, 스페코, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0155 REPLACE INTO company_info VALUES (139050, 시티랩스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #0156 REPLACE INTO company_info VALUES (344050, 신영스팩6호, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# ...
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2432 REPLACE INTO company_info VALUES (054450, 텔레칩스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2433 REPLACE INTO company_info VALUES (091440, 텔레필드, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2434 REPLACE INTO company_info VALUES (104480, 티케이케미칼, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2435 REPLACE INTO company_info VALUES (081150, 티플랙스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2436 REPLACE INTO company_info VALUES (170790, 파이오링크, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2437 REPLACE INTO company_info VALUES (049120, 파인디앤씨, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2438 REPLACE INTO company_info VALUES (009520, 포스코엠텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2439 REPLACE INTO company_info VALUES (189690, 포시에스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2440 REPLACE INTO company_info VALUES (094940, 푸른기술, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2441 REPLACE INTO company_info VALUES (035200, 프럼파스트, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2442 REPLACE INTO company_info VALUES (334970, 프레스티지바이오로직스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2443 REPLACE INTO company_info VALUES (300080, 플리토, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2444 REPLACE INTO company_info VALUES (299030, 하나기술, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2445 REPLACE INTO company_info VALUES (136480, 하림, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2446 REPLACE INTO company_info VALUES (013030, 하이록코리아, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2447 REPLACE INTO company_info VALUES (126700, 하이비젼시스템, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2448 REPLACE INTO company_info VALUES (066130, 하츠, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2449 REPLACE INTO company_info VALUES (034950, 한국기업평가, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2450 REPLACE INTO company_info VALUES (017890, 한국알콜, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2451 REPLACE INTO company_info VALUES (063570, 한국전자금융, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2452 REPLACE INTO company_info VALUES (039740, 한국정보공학, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2453 REPLACE INTO company_info VALUES (052600, 한네트, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2454 REPLACE INTO company_info VALUES (092460, 한라IMS, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2455 REPLACE INTO company_info VALUES (042520, 한스바이오메드, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2456 REPLACE INTO company_info VALUES (054920, 한컴위드, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2457 REPLACE INTO company_info VALUES (016790, 현대사료, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2458 REPLACE INTO company_info VALUES (060560, 홈센타홀딩스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2459 REPLACE INTO company_info VALUES (028080, 휴맥스홀딩스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2460 REPLACE INTO company_info VALUES (238490, 힘스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2461 REPLACE INTO company_info VALUES (288490, 나라소프트, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2462 REPLACE INTO company_info VALUES (176750, 듀켐바이오, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2463 REPLACE INTO company_info VALUES (200350, 래몽래인, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2464 REPLACE INTO company_info VALUES (236340, 메디젠휴먼케어, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2465 REPLACE INTO company_info VALUES (224810, 엄지하우스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2466 REPLACE INTO company_info VALUES (224020, 에스케이씨에스, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2467 REPLACE INTO company_info VALUES (207490, 에이펙스인텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2468 REPLACE INTO company_info VALUES (329020, 오션스톤, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2469 REPLACE INTO company_info VALUES (216280, 원텍, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2470 REPLACE INTO company_info VALUES (122830, 원포유, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2471 REPLACE INTO company_info VALUES (140660, 위월드, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2472 REPLACE INTO company_info VALUES (232530, 이엠티, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2473 REPLACE INTO company_info VALUES (299480, 지앤이헬스케어, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2474 REPLACE INTO company_info VALUES (327970, 케어룸의료산업, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2475 REPLACE INTO company_info VALUES (189350, 코셋, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2476 REPLACE INTO company_info VALUES (318660, 타임기술, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2477 REPLACE INTO company_info VALUES (393210, 토마토시스템, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2478 REPLACE INTO company_info VALUES (199800, 툴젠, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2479 REPLACE INTO company_info VALUES (217880, 틸론, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2480 REPLACE INTO company_info VALUES (222670, 플럼라인생명과학, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2481 REPLACE INTO company_info VALUES (331660, 한국미라클피플사, 2021-12-07)
# =============
# 0       004840
# 1       155660
# 2       078930
# 3       001250
# 4       294870
#          ...
# 2477    199800
# 2478    217880
# 2479    222670
# 2480    331660
# 2481    212310
# Name: code, Length: 2482, dtype: object
# [2021-12-07 14:21] #2482 REPLACE INTO company_info VALUES (212310, 휴벡셀, 2021-12-07)
#
# [2021-12-07 14:22] #0001 DRB동일 (004840) : 100 rows > REPLACE INTO daily_price [OK]
# [2021-12-07 14:22] #0002 DSR (155660) : 100 rows > REPLACE INTO daily_price [OK]
# [2021-12-07 14:22] #0003 GS (078930) : 100 rows > REPLACE INTO daily_price [OK]
# [2021-12-07 14:22] #0004 GS글로벌 (001250) : 100 rows > REPLACE INTO daily_price [OK]
# [2021-12-07 14:22] #0005 HDC현대산업개발 (294870) : 100 rows > REPLACE INTO daily_price [OK]
